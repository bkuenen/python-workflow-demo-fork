# %% [markdown]
# Classic notebook. Not great for version management.

# %%
from hhnk_threedi_tools.core.api.calculation_gui_class import StartCalculationGui
from IPython.display import HTML, display

display(HTML("<style>.container {width:90% !important;}</style>"))

self = StartCalculationGui(data={})
display(self.tab)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/codespace/.local/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/codespace/.local/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/codespace/.local/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/codespace/.local/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/asyncio/base_events.py", line 645, in run_forever
#     self._run_once()
#   File "/workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/asyncio/base_events.py", line 1999, in _run_once
#     handle._run()
#   File "/workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/codespace/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/codespace/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/codespace/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/codespace/.local/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/codespace/.local/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/codespace/.local/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/codespace/.local/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/codespace/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3047, in run_cell
#     result = self._run_cell(
#   File "/home/codespace/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3102, in _run_cell
#     result = runner(coro)
#   File "/home/codespace/.local/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/codespace/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3306, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/codespace/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3489, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/codespace/.local/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3549, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_35011/2506007582.py", line 1, in <module>
#     from hhnk_threedi_tools.core.api.calculation_gui_class import StartCalculationGui
#   File "/workspaces/hhnk-threedi-tools/hhnk_threedi_tools/__init__.py", line 15, in <module>
#     from hhnk_threedi_tools.core.checks.sqlite.sqlite_main import SqliteCheck  # FIXME
#   File "/workspaces/hhnk-threedi-tools/hhnk_threedi_tools/core/checks/sqlite/sqlite_main.py", line 22, in <module>
#     from threedigrid_builder import make_gridadmin
#   File "/workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/site-packages/threedigrid_builder/__init__.py", line 1, in <module>
#     from .application import *  # NOQA
#   File "/workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/site-packages/threedigrid_builder/application.py", line 17, in <module>
#     from threedigrid_builder.grid import Grid, QuadTree
#   File "/workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/site-packages/threedigrid_builder/grid/__init__.py", line 22, in <module>
#     from .quadtree import *  # NOQA
#   File "/workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/site-packages/threedigrid_builder/grid/quadtree.py", line 11, in <module>
#     from .fgrid import m_cells, m_quadtree
#   File "/workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/site-packages/threedigrid_builder/grid/fgrid/__init__.py", line 1, in <module>
#     from ._fgrid import m_cells, m_quadtree  # NOQA
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/numpy/core/_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.4 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from hhnk_threedi_tools.core.api.calculation_gui_class import StartCalculationGui
#       2 from IPython.display import HTML, display
#       4 display(HTML("<style>.container {width:90% !important;}</style>"))
#
# File /workspaces/hhnk-threedi-tools/hhnk_threedi_tools/__init__.py:15
#      13 # FIXME TypeError: metaclass conflict: the metaclass of a derived class must be a (non-strict) subclass of the metaclasses of all its bases
#      14 from hhnk_threedi_tools.core.checks.one_d_two_d import OneDTwoDTest
# ---> 15 from hhnk_threedi_tools.core.checks.sqlite.sqlite_main import SqliteCheck  # FIXME
#      16 from hhnk_threedi_tools.core.checks.zero_d_one_d import ZeroDOneDTest
#      17 from hhnk_threedi_tools.core.folders import Folders
#
# File /workspaces/hhnk-threedi-tools/hhnk_threedi_tools/core/checks/sqlite/sqlite_main.py:22
#      20 from shapely import wkt
#      21 from shapely.geometry import Point
# ---> 22 from threedigrid_builder import make_gridadmin
#      24 from hhnk_threedi_tools.core.checks.sqlite.structure_control import StructureControl
#      26 # Local imports
#
# File /workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/site-packages/threedigrid_builder/__init__.py:1
# ----> 1 from .application import *  # NOQA
#       2 from .exceptions import *  # NOQA
#       4 # fmt: off
#
# File /workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/site-packages/threedigrid_builder/application.py:17
#      15 from threedigrid_builder.constants import InflowType
#      16 from threedigrid_builder.exceptions import SchematisationError
# ---> 17 from threedigrid_builder.grid import Grid, QuadTree
#      18 from threedigrid_builder.grid.zero_d import ImperviousSurfaces
#      19 from threedigrid_builder.interface import (
#      20     DictOut,
#      21     GDALInterface,
#    (...)     24     SQLite,
#      25 )
#
# File /workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/site-packages/threedigrid_builder/grid/__init__.py:22
#      20 from .pipes import *  # NOQA
#      21 from .potential_breaches import *  # NOQA
# ---> 22 from .quadtree import *  # NOQA
#      23 from .structures import *  # NOQA
#      24 from .windshielding import *  # NOQA
#
# File /workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/site-packages/threedigrid_builder/grid/quadtree.py:11
#       8 from threedigrid_builder.constants import LineType, NodeType
#       9 from threedigrid_builder.exceptions import SchematisationError
# ---> 11 from .fgrid import m_cells, m_quadtree
#      13 logger = logging.getLogger(__name__)
#      16 __all__ = ["QuadTree"]
#
# File /workspaces/python-workflow-demo-fork/.pixi/envs/default/lib/python3.12/site-packages/threedigrid_builder/grid/fgrid/__init__.py:1
# ----> 1 from ._fgrid import m_cells, m_quadtree  # NOQA
#
# ImportError: numpy.core.multiarray failed to import

# %%
import numpy as np
import pandas as pd
import geopandas as gpd

# %%
pd.DataFrame()
